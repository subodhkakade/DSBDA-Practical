# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('AirQuality.csv',sep=';')
df
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
#DATA CLEANING AND CORRECTING ERROR
numeric_data = df.drop(columns=['Unnamed: 15','Unnamed: 16'])
numeric_data
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
numeric_data.isnull().sum()
# Out:
# Date             114
# Time             114
# CO(GT)           114
# PT08.S1(CO)      114
# NMHC(GT)         114
# C6H6(GT)         114
# PT08.S2(NMHC)    114
# NOx(GT)          114
# PT08.S3(NOx)     114
# NO2(GT)          114
# PT08.S4(NO2)     114
# PT08.S5(O3)      114
# T                114
# RH               114
# AH               114
# dtype: int64

# %%
numeric_data.fillna(method="ffill",inplace=True)

# %%
numeric_data.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %%
#DATA TRANSFORMATION AND INTEGRATION BY DIVIDING INTO SUBSETS AND THEN ITEGRATING IT INTO ONE
subset1 = df[df['CO(GT)']=='2,2']
subset1
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 15    11/03/2004  09.00.00    2,2       1351.0      87.0      9,5
# 21    11/03/2004  15.00.00    2,2       1310.0      79.0      8,8
# 22    11/03/2004  16.00.00    2,2       1292.0      95.0      8,3
# ...          ...       ...    ...          ...       ...      ...
# 9466  04/04/2005  14.00.00    2,2       1071.0    -200.0     11,9
# 9467  04/04/2005  14.00.00    2,2       1071.0    -200.0     11,9
# 9468  04/04/2005  14.00.00    2,2       1071.0    -200.0     11,9
# 9469  04/04/2005  14.00.00    2,2       1071.0    -200.0     11,9
# 9470  04/04/2005  14.00.00    2,2       1071.0    -200.0     11,9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 2             939.0    131.0        1140.0    114.0        1555.0
# ...

# %%
subset2 = df[df['C6H6(GT)']=='11,9']
subset2
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 79    14/03/2004  01.00.00    2,8       1484.0     131.0     11,9
# 94    14/03/2004  16.00.00      3       1458.0     150.0     11,9
# 481   30/03/2004  19.00.00    2,7       1334.0     301.0     11,9
# 573   03/04/2004  15.00.00   -200       1331.0    -200.0     11,9
# ...          ...       ...    ...          ...       ...      ...
# 9466  04/04/2005  14.00.00    2,2       1071.0    -200.0     11,9
# 9467  04/04/2005  14.00.00    2,2       1071.0    -200.0     11,9
# 9468  04/04/2005  14.00.00    2,2       1071.0    -200.0     11,9
# 9469  04/04/2005  14.00.00    2,2       1071.0    -200.0     11,9
# 9470  04/04/2005  14.00.00    2,2       1071.0    -200.0     11,9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
df_modified = [subset1,subset2]

# %%
pd.concat(df_modified)
#This concatinates the two different subsets into a new subset
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 15    11/03/2004  09.00.00    2,2       1351.0      87.0      9,5
# 21    11/03/2004  15.00.00    2,2       1310.0      79.0      8,8
# 22    11/03/2004  16.00.00    2,2       1292.0      95.0      8,3
# ...          ...       ...    ...          ...       ...      ...
# 9466  04/04/2005  14.00.00    2,2       1071.0    -200.0     11,9
# 9467  04/04/2005  14.00.00    2,2       1071.0    -200.0     11,9
# 9468  04/04/2005  14.00.00    2,2       1071.0    -200.0     11,9
# 9469  04/04/2005  14.00.00    2,2       1071.0    -200.0     11,9
# 9470  04/04/2005  14.00.00    2,2       1071.0    -200.0     11,9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 2             939.0    131.0        1140.0    114.0        1555.0
# ...
