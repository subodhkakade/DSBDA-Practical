# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Heart.csv')

# %%
df
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
# 5           6   56    1    nontypical     120   236    0        0    178
# 6           7   62    0  asymptomatic     140   268    0        2    160
# 7           8   57    0  asymptomatic     120   354    0        0    163
# 8           9   63    1  asymptomatic     130   254    0        2    147
# 9          10   53    1  asymptomatic     140   203    1        2    155
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Age', 'Sex', 'ChestPain', 'RestBP', 'Chol', 'Fbs',
#        'RestECG', 'MaxHR', 'ExAng', 'Oldpeak', 'Slope', 'Ca', 'Thal', 'AHD'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# Age             int64
# Sex             int64
# ChestPain      object
# RestBP          int64
# Chol            int64
# Fbs             int64
# RestECG         int64
# MaxHR           int64
# ExAng           int64
# Oldpeak       float64
# Slope           int64
# Ca            float64
# Thal           object
# AHD            object
# dtype: object

# %%
#Line Plot using Seaborn
sns.lineplot(x='Age', y='RestBP', data = df)
plt.title('RestBP Vs Age')
# Out:
# Text(0.5, 1.0, 'RestBP Vs Age')

# %%
#Displot using Seaborn
sns.displot(df['Chol']);

# %%
#Histogram Plot using Seaborn
sns.histplot(df['ChestPain'])
# Out:
# <AxesSubplot:xlabel='ChestPain', ylabel='Count'>

# %%
#Scatter Plot using Seaborn
sns.scatterplot(x = 'Age', y = 'RestBP', data = df, hue = 'Sex')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='RestBP'>

# %%
#Bar Plot using Seaborn
sns.barplot(y = 'Chol', x = 'ChestPain', data = df)
# Out:
# <AxesSubplot:xlabel='ChestPain', ylabel='Chol'>

# %%
#Pair Plot using Seaborn
sns.pairplot(df, hue = 'Sex')
plt.figure(figsize=(12,12))

# %%
#Scatter Plot using Matplot 
plt.scatter(df['Age'], df['RestBP'], color = 'red')
plt.title('RestBP as per age')
plt.xlabel('Age')
plt.ylabel('RestBP')


#can change marker = 'v' or '.'
# Out:
# Text(0, 0.5, 'RestBP')

# %%
#Line Plot using Matplot
plt.plot(df['RestBP'], df['Sex'])

# %%
#Initializing a new df with Sex value counts
sex_df = pd.DataFrame(df['Sex'].value_counts())
sex_df
# Out:
#    Sex
# 1  206
# 0   97

# %%
#PiePlot using Matplot
plt.pie(sex_df['Sex'],labels = sex_df.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x24dc7fb2eb0>,
# ...
#  [Text(-0.5890242258008583, 0.9290050922463771, '1'),
#   Text(0.5890242258008579, -0.9290050922463774, '0')])

# %%
#Bar Plot using Matplot
plt.bar(sex_df.index,sex_df['Sex'])
# Out:
# <BarContainer object of 2 artists>

# %%
#Pie Plot of ChestPain
data = [df.ChestPain[df.ChestPain == "typical"].count(),df.ChestPain[df.ChestPain == "asymptomatic"].count(),
       df.ChestPain[df.ChestPain == "nonanginal"].count(),df.ChestPain[df.ChestPain == "nontypical"].count()]
labels = ["nonanginal","typical","nontypical","asymptomaic"]
plt.pie(data,labels=labels)
plt.show()
